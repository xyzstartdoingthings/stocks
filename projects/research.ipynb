# %% [markdown]
# ![QuantConnect Logo](https://cdn.quantconnect.com/web/i/icon.png)
# <hr>

# %%
# QuantBook Analysis Tool 
# For more information see [https://www.quantconnect.com/docs/v2/our-platform/research/getting-started]
qb = QuantBook()
spy = qb.AddEquity("SPY")
# Locally Lean installs free sample data, to download more data please visit https://www.quantconnect.com/docs/v2/lean-cli/datasets/downloading-data 
qb.SetStartDate(2013, 10, 11)
history = qb.History(qb.Securities.Keys, 360, Resolution.Daily)

# Indicator Analysis
bbdf = qb.Indicator(BollingerBands(30, 2), spy.Symbol, 360, Resolution.Daily)
bbdf.drop('standarddeviation', axis=1).plot()
# Out:
# 20230805 20:45:50.700 TRACE:: QuantBook started; Is Python: True
# 20230805 20:45:50.739 TRACE:: Config.GetValue(): downloader-data-update-period - Using default value: 7
# 20230805 20:45:50.977 TRACE:: Config.GetValue(): qb-data-hour - Using default value: 9
# 20230805 20:45:50.981 TRACE:: Config.Get(): Configuration key not found. Key: data-permission-manager - Using default value: DataPermissionManager
# 20230805 20:45:50.982 TRACE:: Config.Get(): Configuration key not found. Key: lean-manager-type - Using default value: LocalLeanManager
# 20230805 20:45:50.983 TRACE:: Config.GetValue(): scheduled-event-leaky-bucket-capacity - Using default value: 120
# 20230805 20:45:50.984 TRACE:: Config.GetValue(): scheduled-event-leaky-bucket-time-interval-minutes - Using default value: 1440
# 20230805 20:45:50.984 TRACE:: Config.GetValue(): scheduled-event-leaky-bucket-refill-amount - Using default value: 18
# 20230805 20:45:50.985 TRACE:: Config.GetValue(): algorithm-manager-time-loop-maximum - Using default value: 20
# 20230805 20:45:50.985 TRACE:: Config.GetValue(): project-id - Using default value: 0
# 20230805 20:45:50.986 TRACE:: Config.Get(): Configuration key not found. Key: job-organization-id - Using default value:
# 20230805 20:45:50.986 TRACE:: Config.GetValue(): storage-limit - Using default value: 10737418240
# 20230805 20:45:50.987 TRACE:: Config.GetValue(): storage-permissions - Using default value: 3
# 20230805 20:45:50.987 TRACE:: LocalObjectStore.Initialize(): Storage Root: /Storage. StorageFileCount 9999999. StorageLimit 10240MB
# 20230805 20:45:50.995 TRACE:: HistoryProviderManager.Initialize(): history providers [SubscriptionDataReaderHistoryProvider]
# 20230805 20:45:50.997 TRACE:: Config.GetValue(): deployment-target - Using default value: LocalPlatform
# 20230805 20:45:50.998 TRACE:: Config.GetValue(): qb-data-hour - Using default value: 9
# 20230805 20:45:50.999 TRACE:: Config.Get(): Configuration key not found. Key: data-permission-manager - Using default value: DataPermissionManager
# 20230805 20:45:51.000 TRACE:: Config.Get(): Configuration key not found. Key: lean-manager-type - Using default value: LocalLeanManager
# 20230805 20:45:51.001 TRACE:: Config.GetValue(): algorithm-manager-time-loop-maximum - Using default value: 20
# 20230805 20:45:51.001 TRACE:: Config.GetValue(): project-id - Using default value: 0
# 20230805 20:45:51.002 TRACE:: Config.Get(): Configuration key not found. Key: job-organization-id - Using default value:
# 20230805 20:45:51.002 TRACE:: Config.GetValue(): storage-limit - Using default value: 10737418240
# 20230805 20:45:51.003 TRACE:: Config.GetValue(): storage-permissions - Using default value: 3
# 20230805 20:45:51.003 TRACE:: LocalObjectStore.Initialize(): Storage Root: /Storage. StorageFileCount 9999999. StorageLimit 10240MB
# 20230805 20:45:51.004 TRACE:: HistoryProviderManager.Initialize(): history providers [SubscriptionDataReaderHistoryProvider]
# 20230805 20:45:51.004 TRACE:: Config.GetValue(): deployment-target - Using default value: LocalPlatform
# 20230805 20:45:51.111 TRACE:: Config.GetValue(): data-feed-workers-count - Using default value: 24
# 20230805 20:45:51.113 TRACE:: Config.GetValue(): data-feed-max-work-weight - Using default value: 400
# 20230805 20:45:51.113 TRACE:: WeightedWorkScheduler(): will use 24 workers and MaxWorkWeight is 400
# <Axes: >
