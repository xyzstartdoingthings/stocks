# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/market/v2/get-quotes"

querystring = {"region":"US","symbols":"AMD,IBM,AAPL"}

headers = {
	"X-RapidAPI-Key": "551595c10emsh9ab76ccfb317820p1fa121jsnc738c9455698",
	"X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'quoteResponse': {'result': [{'language': 'en-US', 'region': 'US', 'quoteType': 'EQUITY', 'typeDisp': 'Equity', 'quoteSourceName': 'Nasdaq Real Time Price', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'quoteSummary': {'earnings': {'maxAge': 86400, 'earningsChart': {'quarterly': [{'date': '2Q2022', 'actual': 1.05, 'estimate': 1.03}, {'date': '3Q2022', 'actual': 0.67, 'estimate': 0.68}, {'date': '4Q2022', 'actual': 0.69, 'estimate': 0.67}, {'date': '1Q2023', 'actual': 0.6, 'estimate': 0.56}], 'currentQuarterEstimate': 0.57, 'currentQuarterEstimateDate': '2Q', 'currentQuarterEstimateYear': 2023, 'earningsDate': [1690801140, 1691150400]}, 'financialsChart': {'yearly': [{'date': 2019, 'revenue': 6731000000, 'earnings': 341000000}, {'date': 2020, 'revenue': 9763000000, 'earnings': 2490000000}, {'date': 2021, 'revenue': 16434000000, 'earnings': 3162000000}, {'date': 2022, 'revenue': 23601000000, 'earnings': 1320000000}], 'quarterly': [{'date': '2Q2022', 'revenue': 6550000000, 'earnings': 447000000}, {'date': '3Q2022', 'revenue': 5565000000, 'earnings': 66000000}, {'date': '4Q2022', 'revenue': 5599000000, 'earnings': 21000000}, {'date': '2Q2023', 'revenue': 5353000000, 'earnings': -139000000}]}, 'financialCurrency': 'USD'}}, 'currency': 'USD', 'totalCash': 5938999800.0, 'floatShares': 1601134496, 'ebitda': 3976999936, 'shortRatio': 0.57, 'preMarketChange': -0.690002, 'preMarketChangePercent': -0.638891, 'preMarketTime': 1684848599, 'targetPriceHigh': 200.0, 'targetPriceLow': 60.0, 'targetPriceMean': 102.37, 'targetPriceMedian': 100.0, 'preMarketPrice': 107.31, 'heldPercentInsiders': 0.453, 'heldPercentInstitutions': 73.246, 'postMarketChangePercent': -0.12948519, 'postMarketTime': 1684875627, 'postMarketPrice': 107.98, 'postMarketChange': -0.13999939, 'regularMarketChange': 0.12000275, 'regularMarketChangePercent': 0.11111365, 'regularMarketTime': 1684872005, 'regularMarketPrice': 108.12, 'regularMarketDayHigh': 110.99, 'regularMarketDayRange': '107.19 - 110.99', 'regularMarketDayLow': 107.19, 'regularMarketVolume': 72294588, 'sharesShort': 27721747, 'sharesShortPrevMonth': 35253606, 'shortPercentFloat': 1.73, 'regularMarketPreviousClose': 108.0, 'bid': 107.95, 'ask': 107.98, 'bidSize': 14, 'askSize': 9, 'exchange': 'NMS', 'market': 'us_market', 'messageBoardId': 'finmb_168864', 'fullExchangeName': 'NasdaqGS', 'shortName': 'Advanced Micro Devices, Inc.', 'longName': 'Advanced Micro Devices, Inc.', 'regularMarketOpen': 107.25, 'averageDailyVolume3Month': 64336298, 'averageDailyVolume10Day': 70028320, 'beta': 1.936664, 'fiftyTwoWeekLowChange': 53.550003, 'fiftyTwoWeekLowChangePercent': 0.98130846, 'fiftyTwoWeekRange': '54.57 - 110.99', 'fiftyTwoWeekHighChange': -2.869995, 'fiftyTwoWeekHighChangePercent': -0.025858141, 'fiftyTwoWeekLow': 54.57, 'fiftyTwoWeekHigh': 110.99, 'exDividendDate': 798940800, 'earningsTimestamp': 1683061200, 'earningsTimestampStart': 1690801140, 'earningsTimestampEnd': 1691150400, 'trailingAnnualDividendRate': 0.0, 'trailingPE': 569.0527, 'pegRatio': 5.01, 'dividendsPerShare': 0.0, 'trailingAnnualDividendYield': 0.0, 'revenue': 23067000800.0, 'priceToSales': 7.5481043, 'marketState': 'POST', 'epsTrailingTwelveMonths': 0.19, 'epsForward': 4.08, 'epsCurrentYear': 2.83, 'epsNextQuarter': 0.73, 'priceEpsCurrentYear': 38.20495, 'priceEpsNextQuarter': 148.10959, 'sharesOutstanding': 1610360064, 'bookValue': 33.993, 'fiftyDayAverage': 93.844, 'fiftyDayAverageChange': 14.276001, 'fiftyDayAverageChangePercent': 0.1521248, 'twoHundredDayAverage': 79.32055, 'twoHundredDayAverageChange': 28.799454, 'twoHundredDayAverageChangePercent': 0.36307684, 'marketCap': 174112129024, 'forwardPE': 26.500002, 'priceToBook': 3.180655, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'pageViews': {'midTermTrend': 'UP', 'longTermTrend': 'UP', 'shortTermTrend': 'DOWN'}, 'gmtOffSetMilliseconds': -14400000, 'esgPopulated': False, 'tradeable': False ...

# %%
for key in response.json()['quoteResponse']['result']:
    print(key)
# Out:
# {'language': 'en-US', 'region': 'US', 'quoteType': 'EQUITY', 'typeDisp': 'Equity', 'quoteSourceName': 'Nasdaq Real Time Price', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'quoteSummary': {'earnings': {'maxAge': 86400, 'earningsChart': {'quarterly': [{'date': '2Q2022', 'actual': 1.05, 'estimate': 1.03}, {'date': '3Q2022', 'actual': 0.67, 'estimate': 0.68}, {'date': '4Q2022', 'actual': 0.69, 'estimate': 0.67}, {'date': '1Q2023', 'actual': 0.6, 'estimate': 0.56}], 'currentQuarterEstimate': 0.57, 'currentQuarterEstimateDate': '2Q', 'currentQuarterEstimateYear': 2023, 'earningsDate': [1690801140, 1691150400]}, 'financialsChart': {'yearly': [{'date': 2019, 'revenue': 6731000000, 'earnings': 341000000}, {'date': 2020, 'revenue': 9763000000, 'earnings': 2490000000}, {'date': 2021, 'revenue': 16434000000, 'earnings': 3162000000}, {'date': 2022, 'revenue': 23601000000, 'earnings': 1320000000}], 'quarterly': [{'date': '2Q2022', 'revenue': 6550000000, 'earnings': 447000000}, {'date': '3Q2022', 'revenue': 5565000000, 'earnings': 66000000}, {'date': '4Q2022', 'revenue': 5599000000, 'earnings': 21000000}, {'date': '2Q2023', 'revenue': 5353000000, 'earnings': -139000000}]}, 'financialCurrency': 'USD'}}, 'currency': 'USD', 'totalCash': 5938999800.0, 'floatShares': 1601134496, 'ebitda': 3976999936, 'shortRatio': 0.57, 'preMarketChange': -0.690002, 'preMarketChangePercent': -0.638891, 'preMarketTime': 1684848599, 'targetPriceHigh': 200.0, 'targetPriceLow': 60.0, 'targetPriceMean': 102.37, 'targetPriceMedian': 100.0, 'preMarketPrice': 107.31, 'heldPercentInsiders': 0.453, 'heldPercentInstitutions': 73.246, 'postMarketChangePercent': -0.12948519, 'postMarketTime': 1684875627, 'postMarketPrice': 107.98, 'postMarketChange': -0.13999939, 'regularMarketChange': 0.12000275, 'regularMarketChangePercent': 0.11111365, 'regularMarketTime': 1684872005, 'regularMarketPrice': 108.12, 'regularMarketDayHigh': 110.99, 'regularMarketDayRange': '107.19 - 110.99', 'regularMarketDayLow': 107.19, 'regularMarketVolume': 72294588, 'sharesShort': 27721747, 'sharesShortPrevMonth': 35253606, 'shortPercentFloat': 1.73, 'regularMarketPreviousClose': 108.0, 'bid': 107.95, 'ask': 107.98, 'bidSize': 14, 'askSize': 9, 'exchange': 'NMS', 'market': 'us_market', 'messageBoardId': 'finmb_168864', 'fullExchangeName': 'NasdaqGS', 'shortName': 'Advanced Micro Devices, Inc.', 'longName': 'Advanced Micro Devices, Inc.', 'regularMarketOpen': 107.25, 'averageDailyVolume3Month': 64336298, 'averageDailyVolume10Day': 70028320, 'beta': 1.936664, 'fiftyTwoWeekLowChange': 53.550003, 'fiftyTwoWeekLowChangePercent': 0.98130846, 'fiftyTwoWeekRange': '54.57 - 110.99', 'fiftyTwoWeekHighChange': -2.869995, 'fiftyTwoWeekHighChangePercent': -0.025858141, 'fiftyTwoWeekLow': 54.57, 'fiftyTwoWeekHigh': 110.99, 'exDividendDate': 798940800, 'earningsTimestamp': 1683061200, 'earningsTimestampStart': 1690801140, 'earningsTimestampEnd': 1691150400, 'trailingAnnualDividendRate': 0.0, 'trailingPE': 569.0527, 'pegRatio': 5.01, 'dividendsPerShare': 0.0, 'trailingAnnualDividendYield': 0.0, 'revenue': 23067000800.0, 'priceToSales': 7.5481043, 'marketState': 'POST', 'epsTrailingTwelveMonths': 0.19, 'epsForward': 4.08, 'epsCurrentYear': 2.83, 'epsNextQuarter': 0.73, 'priceEpsCurrentYear': 38.20495, 'priceEpsNextQuarter': 148.10959, 'sharesOutstanding': 1610360064, 'bookValue': 33.993, 'fiftyDayAverage': 93.844, 'fiftyDayAverageChange': 14.276001, 'fiftyDayAverageChangePercent': 0.1521248, 'twoHundredDayAverage': 79.32055, 'twoHundredDayAverageChange': 28.799454, 'twoHundredDayAverageChangePercent': 0.36307684, 'marketCap': 174112129024, 'forwardPE': 26.500002, 'priceToBook': 3.180655, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'pageViews': {'midTermTrend': 'UP', 'longTermTrend': 'UP', 'shortTermTrend': 'DOWN'}, 'gmtOffSetMilliseconds': -14400000, 'esgPopulated': False, 'tradeable': False, 'cryptoTradeable': False, 'f ...
# {'language': 'en-US', 'region': 'US', 'quoteType': 'EQUITY', 'typeDisp': 'Equity', 'quoteSourceName': 'Nasdaq Real Time Price', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'quoteSummary': {'earnings': {'maxAge': 86400, 'earningsChart': {'quarterly': [{'date': '2Q2022', 'actual': 2.31, 'estimate': 2.27}, {'date': '3Q2022', 'actual': 1.81, 'estimate': 1.77}, {'date': '4Q2022', 'actual': 3.6, 'estimate': 3.6}, {'date': '1Q2023', 'actual': 1.36, 'estimate': 1.26}], 'currentQuarterEstimate': 2.0, 'currentQuarterEstimateDate': '2Q', 'currentQuarterEstimateYear': 2023, 'earningsDate': [1689796800]}, 'financialsChart': {'yearly': [{'date': 2019, 'revenue': 57714000000, 'earnings': 9431000000}, {'date': 2020, 'revenue': 55179000000, 'earnings': 5590000000}, {'date': 2021, 'revenue': 57351000000, 'earnings': 5743000000}, {'date': 2022, 'revenue': 60530000000, 'earnings': 1639000000}], 'quarterly': [{'date': '2Q2022', 'revenue': 15535000000, 'earnings': 1392000000}, {'date': '3Q2022', 'revenue': 14107000000, 'earnings': -3196000000}, {'date': '4Q2022', 'revenue': 16690000000, 'earnings': 2710000000}, {'date': '1Q2023', 'revenue': 14251000000, 'earnings': 927000000}]}, 'financialCurrency': 'USD'}}, 'currency': 'USD', 'totalCash': 17393999900.0, 'floatShares': 906973920, 'ebitda': 12643999744, 'shortRatio': 6.13, 'preMarketChange': -0.260002, 'preMarketChangePercent': -0.203923, 'preMarketTime': 1684848599, 'targetPriceHigh': 162.0, 'targetPriceLow': 110.0, 'targetPriceMean': 140.79, 'targetPriceMedian': 140.0, 'preMarketPrice': 127.24, 'heldPercentInsiders': 0.087, 'heldPercentInstitutions': 59.409, 'postMarketChangePercent': -0.19503228, 'postMarketTime': 1684875614, 'postMarketPrice': 127.93, 'postMarketChange': -0.24999237, 'regularMarketChange': 0.6799927, 'regularMarketChangePercent': 0.5333276, 'regularMarketTime': 1684872002, 'regularMarketPrice': 128.18, 'regularMarketDayHigh': 129.09, 'regularMarketDayRange': '127.13 - 129.09', 'regularMarketDayLow': 127.13, 'regularMarketVolume': 3595726, 'sharesShort': 26108365, 'sharesShortPrevMonth': 23815369, 'shortPercentFloat': 2.88, 'regularMarketPreviousClose': 127.5, 'bid': 128.17, 'ask': 128.21, 'bidSize': 8, 'askSize': 8, 'exchange': 'NYQ', 'market': 'us_market', 'messageBoardId': 'finmb_112350', 'fullExchangeName': 'NYSE', 'shortName': 'International Business Machines', 'longName': 'International Business Machines Corporation', 'regularMarketOpen': 127.24, 'averageDailyVolume3Month': 4844106, 'averageDailyVolume10Day': 3782460, 'beta': 0.850457, 'fiftyTwoWeekLowChange': 12.62999, 'fiftyTwoWeekLowChangePercent': 0.109303236, 'fiftyTwoWeekRange': '115.55 - 153.21', 'fiftyTwoWeekHighChange': -25.030014, 'fiftyTwoWeekHighChangePercent': -0.16337062, 'fiftyTwoWeekLow': 115.55, 'fiftyTwoWeekHigh': 153.21, 'dividendDate': 1686355200, 'exDividendDate': 1683590400, 'earningsTimestamp': 1689796800, 'earningsTimestampStart': 1689796800, 'earningsTimestampEnd': 1689796800, 'trailingAnnualDividendRate': 6.6, 'trailingPE': 57.22321, 'pegRatio': 2.04, 'dividendsPerShare': 6.6, 'dividendRate': 6.64, 'trailingAnnualDividendYield': 0.051764704, 'dividendYield': 5.21, 'revenue': 60585001000.0, 'priceToSales': 1.9211553, 'marketState': 'POST', 'epsTrailingTwelveMonths': 2.24, 'epsForward': 10.02, 'epsCurrentYear': 9.43, 'epsNextQuarter': 2.15, 'priceEpsCurrentYear': 13.592788, 'priceEpsNextQuarter': 59.6186, 'sharesOutstanding': 908044992, 'bookValue': 23.792, 'fiftyDayAverage': 126.3468, 'fiftyDayAverageChange': 1.8331909, 'fiftyDayAverageChangePercent': 0.014509199, 'twoHundredDayAverage': 132.91795, 'twoHundredDayAverageChange': -4.737961, 'twoHundredDayAverageChangePercent': -0.035645757, 'marketCap': 116393197568, 'forwardPE': 12.792414, 'priceToBook': 5.387525, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'pageViews': {'midTermTrend': 'UP', 'longTermTrend': 'UP', 'shortTermTrend': 'DOWN'}, 'gmtOffSe ...
# {'language': 'en-US', 'region': 'US', 'quoteType': 'EQUITY', 'typeDisp': 'Equity', 'quoteSourceName': 'Nasdaq Real Time Price', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'quoteSummary': {'earnings': {'maxAge': 86400, 'earningsChart': {'quarterly': [{'date': '2Q2022', 'actual': 1.2, 'estimate': 1.16}, {'date': '3Q2022', 'actual': 1.29, 'estimate': 1.27}, {'date': '4Q2022', 'actual': 1.88, 'estimate': 1.94}, {'date': '1Q2023', 'actual': 1.52, 'estimate': 1.43}], 'currentQuarterEstimate': 1.19, 'currentQuarterEstimateDate': '2Q', 'currentQuarterEstimateYear': 2023, 'earningsDate': [1690401600, 1690833600]}, 'financialsChart': {'yearly': [{'date': 2019, 'revenue': 260174000000, 'earnings': 55256000000}, {'date': 2020, 'revenue': 274515000000, 'earnings': 57411000000}, {'date': 2021, 'revenue': 365817000000, 'earnings': 94680000000}, {'date': 2022, 'revenue': 394328000000, 'earnings': 99803000000}], 'quarterly': [{'date': '2Q2022', 'revenue': 82959000000, 'earnings': 19442000000}, {'date': '3Q2022', 'revenue': 90146000000, 'earnings': 20721000000}, {'date': '4Q2022', 'revenue': 117154000000, 'earnings': 29998000000}, {'date': '2Q2023', 'revenue': 0, 'earnings': 0}]}, 'financialCurrency': 'USD'}}, 'currency': 'USD', 'totalCash': 55872000000.0, 'floatShares': 15712029576, 'ebitda': 123788001280, 'shortRatio': 2.42, 'preMarketChange': -1.03999, 'preMarketChangePercent': -0.597011, 'preMarketTime': 1684848599, 'targetPriceHigh': 209.0, 'targetPriceLow': 118.0, 'targetPriceMean': 178.88, 'targetPriceMedian': 180.0, 'preMarketPrice': 173.16, 'heldPercentInsiders': 0.071, 'heldPercentInstitutions': 61.232, 'postMarketChangePercent': -0.023311544, 'postMarketTime': 1684875617, 'postMarketPrice': 171.52, 'postMarketChange': -0.039993286, 'regularMarketChange': -2.6399994, 'regularMarketChangePercent': -1.5154991, 'regularMarketTime': 1684872004, 'regularMarketPrice': 171.56, 'regularMarketDayHigh': 173.3794, 'regularMarketDayRange': '171.275 - 173.3794', 'regularMarketDayLow': 171.275, 'regularMarketVolume': 46405690, 'sharesShort': 124657645, 'sharesShortPrevMonth': 111566048, 'shortPercentFloat': 0.79, 'regularMarketPreviousClose': 174.2, 'bid': 171.62, 'ask': 171.63, 'bidSize': 8, 'askSize': 9, 'exchange': 'NMS', 'market': 'us_market', 'messageBoardId': 'finmb_24937', 'fullExchangeName': 'NasdaqGS', 'shortName': 'Apple Inc.', 'longName': 'Apple Inc.', 'regularMarketOpen': 173.13, 'averageDailyVolume3Month': 58257373, 'averageDailyVolume10Day': 49615920, 'beta': 1.296622, 'fiftyTwoWeekLowChange': 47.39, 'fiftyTwoWeekLowChangePercent': 0.38165417, 'fiftyTwoWeekRange': '124.17 - 176.39', 'fiftyTwoWeekHighChange': -4.830002, 'fiftyTwoWeekHighChangePercent': -0.027382515, 'fiftyTwoWeekLow': 124.17, 'fiftyTwoWeekHigh': 176.39, 'dividendDate': 1684368000, 'exDividendDate': 1683849600, 'earningsTimestamp': 1683234000, 'earningsTimestampStart': 1690401600, 'earningsTimestampEnd': 1690833600, 'trailingAnnualDividendRate': 0.92, 'trailingPE': 29.028765, 'pegRatio': 3.64, 'dividendsPerShare': 0.92, 'dividendRate': 0.96, 'trailingAnnualDividendYield': 0.005281286, 'dividendYield': 0.55, 'revenue': 385095008000.0, 'priceToSales': 7.0071425, 'marketState': 'POST', 'epsTrailingTwelveMonths': 5.91, 'epsForward': 6.54, 'epsCurrentYear': 5.97, 'epsNextQuarter': 1.36, 'priceEpsCurrentYear': 28.737019, 'priceEpsNextQuarter': 126.14706, 'sharesOutstanding': 15728700416, 'bookValue': 3.953, 'fiftyDayAverage': 165.035, 'fiftyDayAverageChange': 6.524994, 'fiftyDayAverageChangePercent': 0.03953703, 'twoHundredDayAverage': 152.18365, 'twoHundredDayAverageChange': 19.376343, 'twoHundredDayAverageChangePercent': 0.12732211, 'marketCap': 2698415702016, 'forwardPE': 26.232416, 'priceToBook': 43.39995, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'pageViews': {'midTermTrend': 'UP', 'longTermTrend': 'UP', 'shortTermTrend': 'UP'}, 'gmtOffSetMilliseconds': -14400000, 'esg ...

# %%
d = response.json()

# %%
def walk_dict(d):
    for k,v in d.items():
            if isinstance(v, dict):
                walk_dict(v)
            else:
                print("{}: {}".format(k, v))

# %%
walk_dict(d)
# Out:
# result: [{'language': 'en-US', 'region': 'US', 'quoteType': 'EQUITY', 'typeDisp': 'Equity', 'quoteSourceName': 'Nasdaq Real Time Price', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'quoteSummary': {'earnings': {'maxAge': 86400, 'earningsChart': {'quarterly': [{'date': '2Q2022', 'actual': 1.05, 'estimate': 1.03}, {'date': '3Q2022', 'actual': 0.67, 'estimate': 0.68}, {'date': '4Q2022', 'actual': 0.69, 'estimate': 0.67}, {'date': '1Q2023', 'actual': 0.6, 'estimate': 0.56}], 'currentQuarterEstimate': 0.57, 'currentQuarterEstimateDate': '2Q', 'currentQuarterEstimateYear': 2023, 'earningsDate': [1690801140, 1691150400]}, 'financialsChart': {'yearly': [{'date': 2019, 'revenue': 6731000000, 'earnings': 341000000}, {'date': 2020, 'revenue': 9763000000, 'earnings': 2490000000}, {'date': 2021, 'revenue': 16434000000, 'earnings': 3162000000}, {'date': 2022, 'revenue': 23601000000, 'earnings': 1320000000}], 'quarterly': [{'date': '2Q2022', 'revenue': 6550000000, 'earnings': 447000000}, {'date': '3Q2022', 'revenue': 5565000000, 'earnings': 66000000}, {'date': '4Q2022', 'revenue': 5599000000, 'earnings': 21000000}, {'date': '2Q2023', 'revenue': 5353000000, 'earnings': -139000000}]}, 'financialCurrency': 'USD'}}, 'currency': 'USD', 'totalCash': 5938999800.0, 'floatShares': 1601134496, 'ebitda': 3976999936, 'shortRatio': 0.57, 'preMarketChange': -0.690002, 'preMarketChangePercent': -0.638891, 'preMarketTime': 1684848599, 'targetPriceHigh': 200.0, 'targetPriceLow': 60.0, 'targetPriceMean': 102.37, 'targetPriceMedian': 100.0, 'preMarketPrice': 107.31, 'heldPercentInsiders': 0.453, 'heldPercentInstitutions': 73.246, 'postMarketChangePercent': -0.12948519, 'postMarketTime': 1684875627, 'postMarketPrice': 107.98, 'postMarketChange': -0.13999939, 'regularMarketChange': 0.12000275, 'regularMarketChangePercent': 0.11111365, 'regularMarketTime': 1684872005, 'regularMarketPrice': 108.12, 'regularMarketDayHigh': 110.99, 'regularMarketDayRange': '107.19 - 110.99', 'regularMarketDayLow': 107.19, 'regularMarketVolume': 72294588, 'sharesShort': 27721747, 'sharesShortPrevMonth': 35253606, 'shortPercentFloat': 1.73, 'regularMarketPreviousClose': 108.0, 'bid': 107.95, 'ask': 107.98, 'bidSize': 14, 'askSize': 9, 'exchange': 'NMS', 'market': 'us_market', 'messageBoardId': 'finmb_168864', 'fullExchangeName': 'NasdaqGS', 'shortName': 'Advanced Micro Devices, Inc.', 'longName': 'Advanced Micro Devices, Inc.', 'regularMarketOpen': 107.25, 'averageDailyVolume3Month': 64336298, 'averageDailyVolume10Day': 70028320, 'beta': 1.936664, 'fiftyTwoWeekLowChange': 53.550003, 'fiftyTwoWeekLowChangePercent': 0.98130846, 'fiftyTwoWeekRange': '54.57 - 110.99', 'fiftyTwoWeekHighChange': -2.869995, 'fiftyTwoWeekHighChangePercent': -0.025858141, 'fiftyTwoWeekLow': 54.57, 'fiftyTwoWeekHigh': 110.99, 'exDividendDate': 798940800, 'earningsTimestamp': 1683061200, 'earningsTimestampStart': 1690801140, 'earningsTimestampEnd': 1691150400, 'trailingAnnualDividendRate': 0.0, 'trailingPE': 569.0527, 'pegRatio': 5.01, 'dividendsPerShare': 0.0, 'trailingAnnualDividendYield': 0.0, 'revenue': 23067000800.0, 'priceToSales': 7.5481043, 'marketState': 'POST', 'epsTrailingTwelveMonths': 0.19, 'epsForward': 4.08, 'epsCurrentYear': 2.83, 'epsNextQuarter': 0.73, 'priceEpsCurrentYear': 38.20495, 'priceEpsNextQuarter': 148.10959, 'sharesOutstanding': 1610360064, 'bookValue': 33.993, 'fiftyDayAverage': 93.844, 'fiftyDayAverageChange': 14.276001, 'fiftyDayAverageChangePercent': 0.1521248, 'twoHundredDayAverage': 79.32055, 'twoHundredDayAverageChange': 28.799454, 'twoHundredDayAverageChangePercent': 0.36307684, 'marketCap': 174112129024, 'forwardPE': 26.500002, 'priceToBook': 3.180655, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'pageViews': {'midTermTrend': 'UP', 'longTermTrend': 'UP', 'shortTermTrend': 'DOWN'}, 'gmtOffSetMilliseconds': -14400000, 'esgPopulated': False, 'tradeable': False, 'cryptoTradeable':  ...
# error: None

# %%
import pprint

# %%
pprint.pprint(d)
# Out:
# {'quoteResponse': {'error': None,
#                    'result': [{'ask': 107.98,
#                                'askSize': 9,
#                                'averageDailyVolume10Day': 70028320,
#                                'averageDailyVolume3Month': 64336298,
#                                'beta': 1.936664,
#                                'bid': 107.95,
#                                'bidSize': 14,
#                                'bookValue': 33.993,
#                                'components': ['^NQDMXJPLMAUD',
#                                               '^NQDOG',
#                                               '^NQUSBLM',
#                                               '^NQDMXKRMCCADN',
#                                               '^NQDXUSMLTCGN',
#                                               '^NQUS500LCGN',
#                                               '^NQDMXKRMCAUD',
#                                               '^NQUSB9576LMGBPN',
#                                               '^NQUSB9576LM',
#                                               '^NQNALMEURN',
#                                               '^NQSSSEN',
#                                               '^NQUSB9000LMJPYN',
#                                               '^NQUSBLMCAD',
#                                               '^NQUSB9000LMEURN',
#                                               '^NQDMXKRJPYN',
#                                               '^NQDMXKRLMAUDN',
#                                               '^NQNA9000LMGBPN',
#                                               '^NQUSB9570LMJPY',
#                                               '^NQDMXJPLMAUDN',
#                                               '^NQDMXKRLMAUD',
#                                               '^NQUSBLMJPY',
#                                               '^NQNA9000LMEUR',
#                                               '^NQNA9000LMCAD',
#                                               '^NQGXGBLMN',
#                                               '^NQUSB9000LMEUR',
#                                               '^NQDXUSLCEUR',
#                                               '^NQDXUSLCG',
#                                               '^NQUSB9000LMCAD',
#                                               '^NQDM9000LMJPY',
#                                               '^NQG9000LMCADN',
#                                               '^NQDMXKRAUD',
#                                               '^NQDMXKRLMGBPN',
#                                               '^NQGXGBLMGBPN',
#                                               '^NQDM9000LMEURN',
#                                               '^NQGXJPLMJPYN',
#                                               '^NQNALMCADN',
#                                               '^NQUSBLMEUR',
#                                               '^NQG9000LMGBP',
#                                               '^NQDM9000LMJPYN',
#                                               '^NQNALMJPY',
#                                               '^NQGXGBLMJPY',
#                                               '^NQUSB9570LMGBPN',
#                                               '^SOX',
#                                               '^IXCO',
#                                               '^NQGXJPLMJPY',
#                                               '^NQDMXKR',
#                                               '^NQDMXGBLMCADN',
#                                               '^NQUSB9000LMJPY',
#                                               '^NQGXGBLMEURN',
#                                               '^NQGXJPLMCAD',
#                                               '^NQGXJPLMEUR',
#                                               '^NQDMXJPLMGBPN',
#                                               '^NQDMXJPLMN',
#                                               '^NQDMXKRMCEURN',
#                                               '^NQDM9000LMAUD',
#                                               '^NQDMXKRLMCADN',
#                                               '^NQSSSE',
#                                               '^NQUSB9000LMN',
#                                               '^NQDXUSLC',
#                                               '^NQUSB9570LMAUDN',
#                                               '^NQGXGBLMJPYN',
#                                               '^NQG9000LMJPYN',
#                                               '^NQUSBLMEURN',
#                                               '^NQDMXKRMCJPYN',
#                                               '^NQDMXKRJPY',
#                                               '^NQUSB9570LM',
#                                               '^NQUSMLTCG',
#                                               '^NQG9000LMAUD',
#                                               '^NQUSB9576LMGBP',
#                                               '^NQGXJPLMGBPN',
#                                               '^NQUSB9000LMCADN',
#                                               '^IXIC',
#                                               '^NQNALM',
#                                               '^NQUS500LC',
#                                               '^NQDMXGBLMJPY',
#                                               '^NQFFUSGN',
#                                               '^NQNALMAUD',
#                                               '^NQNA9000LMN',
#                                               '^NQDXUSLCN',
#                                               '^NQGXGBLMAUD',
#                                               '^NQUSBLMN',
#                                               '^NQDMXJPLMGBP',
#                                               '^NQUSB9570LMCADN',
#                                               '^NQDMXKRLMEUR',
#                                               '^NQNALMAUDN',
#                                               '^GMB',
#                                               '^NQG9000LMEURN',
#                                               '^NQUSB9576LMJPYN',
#                                               '^NQDM9000LMCADN',
#                                               '^NQDMXKRLMCAD',
#                                               '^NQDMXGBLM',
#                                               '^NQDMXKRMCJPY',
#                                               '^NQUSB9570LMAUD',
#                                               '^NQUSB9576LMAUD',
#                                               '^NQNA9000LMGBP',
#                                               '^NQDMXGBLMJPYN',
#                                               '^NQDOGN',
#                                               '^NQG9000LMN',
#                                               '^NQDMXKRLMJPY',
#                                               '^NQUSBLMJPYN',
#                                               '^NQDM9000LMN',
#                                               '^NQDMXGBLMCAD',
#                                               '^NQDMXGBLMEURN',
#                                               '^NQDMXKRGBPN',
#                                               '^NQDMXGBLMEUR',
#                                               '^NQDMXKRMCEUR',
#                                               '^NQDMXKRAUDN',
#                                               '^NQDMXKRLMJPYN',
#                                               '^NQUSBLMCADN',
#                                               '^NQDMXGBLMN',
#                                               '^NQDMXKRMCCAD',
#                                               '^NQNALMGBPN',
#                                               '^NQGXGBLMCADN',
#                                               '^NQGXJPLMCADN',
#                                               '^NQGXJPLM',
#                                               '^NQUSB9576LMEURN',
#                                               '^NQNA9000LMAUD',
#                                               '^NQUSB9570LMGBP',
#                                               '^NQUSBLMGBP',
#                                               '^NQNALMN',
#                                               '^NQUSB9000LMAUD',
#                                               '^NQNA9000LM',
#                                               '^NQUSB9570LMEURN',
#                                               '^NQDMXKRMCN',
#                                               '^SX',
#                                               '^NQGXJPLMAUDN',
#                                               '^NQDMXKRLM',
#                                               '^NQDM9000LMGBP',
#                                               '^NQUSMLTCGN',
#                                               '^NQNALMGBP',
#                                               '^NQDMXJPLMJPYN',
#                                               '^NQG9000LMEUR',
#                                               '^NQGXGBLM',
#                                               '^NQG9000LMCAD',
#                                               '^NQDMXKRN',
#                                               '^NQUSB9570LMN',
#                                               '^NQDMXKRMCGBPN',
#                                               '^NQCRDN',
#                                               '^NQDMXJPLMEURN',
#                                               '^NQG9000LMJPY',
#                                               '^NQDXUSMLTCG',
#                                               '^NQNA9000LMJPYN',
#                                               '^NQFFUSMN',
#                                               '^NQDMXJPLM',
#                                               '^NQDMXKREUR',
#                                               '^NQGXJPLMGBP',
#                                               '^NQDM9000LMAUDN',
#                                               '^NQDMXKRLMEURN',
#                                               '^NQUSBLMAUD',
#                                               '^NQGXGBLMGBP',
#                                               '^NQDMXKRCAD',
#                                               '^NQDMXKRMC',
#                                               '^NQNA9000LMEURN',
#                                               '^NQUSMGN',
#                                               '^NQUSB9000LMAUDN',
#                                               '^NQUSB9000LMGBP',
#                                               '^NQDXUSLCEURN',
#                                               '^GMBNTR',
#                                               '^NQNA9000LMAUDN',
#                                               '^NQG9000LMAUDN',
#                                               '^NQUSB9576LMN',
#                                               '^XCQ',
#                                               '^NQNALMCAD',
#                                               '^XCI',
#                                               '^NQGXJPLMEURN',
#                                               '^NQDM9000LM',
#                                               '^NQDXUSLCGBP',
#                                               '^NQGXJPLMN',
#                                               '^NQNALMEUR',
#                                               '^NQFFUSG',
#                                               '^RCMP',
#                                               '^NQGXGBLMEUR',
#                                               '^NQUSB9576LMJPY',
#                                               '^NQDMXKRGBP',
#                                               '^NQDM9000LMEUR',
#                                               '^NQFFUSM',
#                                               '^NQDM9000LMCAD',
#                                               '^NQDMXGBLMGBPN',
#                                               '^NQCRD',
#                                               '^NQDMXKRCADN',
#                                               '^NQGXGBLMCAD',
#                                               '^NQDMXGBLMGBP',
#                                               '^NQUSB9576LMCADN',
#                                               '^NQDM9000LMGBPN',
#                                               '^NQDXUSLCGBPN',
#                                               '^NQUSB9570LMJPYN',
#                                               '^NQG9000LM',
#                                               '^NQUSBLMGBPN',
#                                               '^NQDMXKRLMN',
#                                               '^NQGXJPLMAUD',
#                                               '^NQDMXGBLMAUDN',
#                                               '^NQUSB9000LM',
#                                               '^NQDMXJPLMJPY',
#                                               '^NQDXUSLCGN',
#                                               '^NQUS500LCG',
#                                               '^NQDMXKREURN',
#                                               '^NQNALMJPYN',
#                                               '^NQUSB9000LMGBPN',
#                                               '^NQUSB9576LMCAD',
#                                               '^NQG9000LMGBPN',
#                                               '^NQUSB9576LMEUR',
#                                               '^NQDMXJPLMCADN',
#                                               '^NQUSB9570LMCAD',
#                                               '^NQUSB9570LMEUR',
#                                               '^NQDMXKRMCGBP',
#                                               '^NQDMXGBLMAUD',
#                                               '^NQUSBLMAUDN',
#                                               '^NQNA9000LMJPY',
#                                               '^DWUSSR',
#                                               '^NQDMXJPLMCAD',
#                                               '^NQDMXKRMCAUDN',
#                                               '^NQDMXJPLMEUR',
#                                               '^NQDMXKRLMGBP',
#                                               '^NQGXGBLMAUDN',
#                                               '^NQUSB9576LMAUDN',
#                                               '^NQUS500LCN',
#                                               '^NQNA9000LMCADN'],
#                                'cryptoTradeable': False,
#                                'currency': 'USD',
#                                'customPriceAlertConfidence': 'HIGH',
#                                'dividendsPerShare': 0.0,
#                                'earningsTimestamp': 1683061200,
#                                'earningsTimestampEnd': 1691150400,
#                                'earningsTimestampStart': 1690801140,
#                                'ebitda': 3976999936,
#                                'epsCurrentYear': 2.83,
#                                'epsForward': 4.08,
#                                'epsNextQuarter': 0.73,
#                                'epsTrailingTwelveMonths': 0.19,
#                                'esgPopulated': False,
#                                'exDividendDate': 798940800,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 93.844,
#                                'fiftyDayAverageChange': 14.276001,
#                                'fiftyDayAverageChangePercent': 0.1521248,
#                                'fiftyTwoWeekHigh': 110.99,
#                                'fiftyTwoWeekHighChange': -2.869995,
#                                'fiftyTwoWeekHighChangePercent': -0.025858141,
#                                'fiftyTwoWeekLow': 54.57,
#                                'fiftyTwoWeekLowChange': 53.550003,
#                                'fiftyTwoWeekLowChangePercent': 0.98130846,
#                                'fiftyTwoWeekRange': '54.57 - 110.99',
#                                'firstTradeDateMilliseconds': 322151400000,
#                                'floatShares': 1601134496,
#                                'forwardPE': 26.500002,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'heldPercentInsiders': 0.453,
#                                'heldPercentInstitutions': 73.246,
#                                'language': 'en-US',
#                                'longName': 'Advanced Micro Devices, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 174112129024,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_168864',
#                                'pageViews': {'longTermTrend': 'UP',
#                                              'midTermTrend': 'UP',
#                                              'shortTermTrend': 'DOWN'},
#                                'pegRatio': 5.01,
#                                'postMarketChange': -0.13999939,
#                                'postMarketChangePercent': -0.12948519,
#                                'postMarketPrice': 107.98,
#                                'postMarketTime': 1684875627,
#                                'preMarketChange': -0.690002,
#                                'preMarketChangePercent': -0.638891,
#                                'preMarketPrice': 107.31,
#                                'preMarketTime': 1684848599,
#                                'priceEpsCurrentYear': 38.20495,
#                                'priceEpsNextQuarter': 148.10959,
#                                'priceHint': 2,
#                                'priceToBook': 3.180655,
#                                'priceToSales': 7.5481043,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteSummary': {'earnings': {'earningsChart': {'currentQuarterEstimate': 0.57,
#                                                                                'currentQuarterEstimateDate': '2Q',
#                                                                                'currentQuarterEstimateYear': 2023,
#                                                                                'earningsDate': [1690801140,
#                                                                                                 1691150400],
#                                                                                'quarterly': [{'actual': 1.05,
#                                                                                               'date': '2Q2022',
#                                                                                               'estimate': 1.03},
#                                                                                              {'actual': 0.67,
#                                                                                               'date': '3Q2022',
#                                                                                               'estimate': 0.68},
#                                                                                              {'actual': 0.69,
#                                                                                               'date': '4Q2022',
#                                                                                               'estimate': 0.67},
#                                                                                              {'actual': 0.6,
#                                                                                               'date': '1Q2023',
#                                                                                               'estimate': 0.56}]},
#                                                              'financialCurrency': 'USD',
#                                                              'financialsChart': {'quarterly': [{'date': '2Q2022',
#                                                                                                 'earnings': 447000000,
#                                                                                                 'revenue': 6550000000},
#                                                                                                {'date': '3Q2022',
#                                                                                                 'earnings': 66000000,
#                                                                                                 'revenue': 5565000000},
#                                                                                                {'date': '4Q2022',
#                                                                                                 'earnings': 21000000,
#                                                                                                 'revenue': 5599000000},
#                                                                                                {'date': '2Q2023',
#                                                                                                 'earnings': -139000000,
#                                                                                                 'revenue': 5353000000}],
#                                                                                  'yearly': [{'date': 2019,
#                                                                                              'earnings': 341000000,
#                                                                                              'revenue': 6731000000},
#                                                                                             {'date': 2020,
#                                                                                              'earnings': 2490000000,
#                                                                                              'revenue': 9763000000},
#                                                                                             {'date': 2021,
#                                                                                              'earnings': 3162000000,
#                                                                                              'revenue': 16434000000},
#                                                                                             {'date': 2022,
#                                                                                              'earnings': 1320000000,
#                                                                                              'revenue': 23601000000}]},
#                                                              'maxAge': 86400}},
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 0.12000275,
#                                'regularMarketChangePercent': 0.11111365,
#                                'regularMarketDayHigh': 110.99,
#                                'regularMarketDayLow': 107.19,
#                                'regularMarketDayRange': '107.19 - 110.99',
#                                'regularMarketOpen': 107.25,
#                                'regularMarketPreviousClose': 108.0,
#                                'regularMarketPrice': 108.12,
#                                'regularMarketTime': 1684872005,
#                                'regularMarketVolume': 72294588,
#                                'revenue': 23067000800.0,
#                                'sharesOutstanding': 1610360064,
#                                'sharesShort': 27721747,
#                                'sharesShortPrevMonth': 35253606,
#                                'shortName': 'Advanced Micro Devices, Inc.',
#                                'shortPercentFloat': 1.73,
#                                'shortRatio': 0.57,
#                                'sourceInterval': 15,
#                                'symbol': 'AMD',
#                                'targetPriceHigh': 200.0,
#                                'targetPriceLow': 60.0,
#                                'targetPriceMean': 102.37,
#                                'targetPriceMedian': 100.0,
#                                'totalCash': 5938999800.0,
#                                'tradeable': False,
#                                'trailingAnnualDividendRate': 0.0,
#                                'trailingAnnualDividendYield': 0.0,
#                                'trailingPE': 569.0527,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 79.32055,
#                                'twoHundredDayAverageChange': 28.799454,
#                                'twoHundredDayAverageChangePercent': 0.36307684,
#                                'typeDisp': 'Equity'},
#                               {'ask': 128.21,
#                                'askSize': 8,
#                                'averageDailyVolume10Day': 3782460,
#                                'averageDailyVolume3Month': 4844106,
#                                'beta': 0.850457,
#                                'bid': 128.17,
#                                'bidSize': 8,
#                                'bookValue': 23.792,
#                                'components': ['^NQDMXJPLMAUD',
#                                               '^NQUSBLM',
#                                               '^NQSHYL',
#                                               '^NQUSB9533LMAUD',
#                                               '^NQGMOIN',
#                                               '^NQNALMEURN',
#                                               '^NQUSB9000LMJPYN',
#                                               '^NQUSB9530LM',
#                                               '^NQUSBLMCAD',
#                                               '^NQUSB9000LMEURN',
#                                               '^NQDMXKRJPYN',
#                                               '^NQDMXKRLMAUDN',
#                                               '^NQNA9000LMGBPN',
#                                               '^NQDMXJPLMAUDN',
#                                               '^NQDMXKRLMAUD',
#                                               '^NQFFUSHYN',
#                                               '^NQUSBLMJPY',
#                                               '^NQUSHEIN',
#                                               '^NQNA9000LMEUR',
#                                               '^NQNA9000LMCAD',
#                                               '^NQGXGBLMN',
#                                               '^NQUS500LCVN',
#                                               '^NQUSB9533LMEURN',
#                                               '^NQDMXKRLCJPY',
#                                               '^NQUSB9000LMEUR',
#                                               '^NQDXUSLCEUR',
#                                               '^NQUSB9533LMGBP',
#                                               '^CPQ',
#                                               '^CPQNTR',
#                                               '^NQUSB9000LMCAD',
#                                               '^NQUSB9533LMJPYN',
#                                               '^NQDM9000LMJPY',
#                                               '^NQG9000LMCADN',
#                                               '^NQDMXKRAUD',
#                                               '^NQDMXKRLMGBPN',
#                                               '^NQDXUSMLTCVN',
#                                               '^NQGXGBLMGBPN',
#                                               '^NQDM9000LMEURN',
#                                               '^NQGXJPLMJPYN',
#                                               '^NQNALMCADN',
#                                               '^NQUSBLMEUR',
#                                               '^NQG9000LMGBP',
#                                               '^NQDM9000LMJPYN',
#                                               '^NQNALMJPY',
#                                               '^NQUSHEI',
#                                               '^DAA',
#                                               '^MSH',
#                                               '^NQGXGBLMJPY',
#                                               '^QCRD',
#                                               '^NQGXJPLMJPY',
#                                               '^NQUSB9530LMCAD',
#                                               '^NQUSB9530LMGBPN',
#                                               '^NQDMXKR',
#                                               '^NQDMXGBLMCADN',
#                                               '^NQUSB9530LMEUR',
#                                               '^NQUSHEIEURN',
#                                               '^NQUSB9000LMJPY',
#                                               '^NQDMXKRLCN',
#                                               '^NQGXGBLMEURN',
#                                               '^NQGXJPLMCAD',
#                                               '^NQUSB9530LMN',
#                                               '^NQGXJPLMEUR',
#                                               '^NQUSB9530LMGBP',
#                                               '^NQDMXJPLMGBPN',
#                                               '^NQUSLV',
#                                               '^NQDMXJPLMN',
#                                               '^NQGIHEIGBP',
#                                               '^NQDM9000LMAUD',
#                                               '^NQDMXKRLCJPYN',
#                                               '^NQDMXKRLMCADN',
#                                               '^NQDMXKRLCEUR',
#                                               '^NQUSB9000LMN',
#                                               '^NQDXUSLC',
#                                               '^NQGXGBLMJPYN',
#                                               '^IBMSY',
#                                               '^NQG9000LMJPYN',
#                                               '^NQGIHEIGBPN',
#                                               '^NQUSBLMEURN',
#                                               '^NQDMXKRJPY',
#                                               '^NQDMXKRLCCAD',
#                                               '^NQDMXKRLCEURN',
#                                               '^NQG9000LMAUD',
#                                               '^NQUSHEIGBPN',
#                                               '^NQGXJPLMGBPN',
#                                               '^NQUSB9000LMCADN',
#                                               '^NQNALM',
#                                               '^NQUS500LC',
#                                               '^NQDMXGBLMJPY',
#                                               '^NQUSMLTCV',
#                                               '^NQNALMAUD',
#                                               '^NQNA9000LMN',
#                                               '^NQVMVUS',
#                                               '^NQDXUSLCN',
#                                               '^NQGXGBLMAUD',
#                                               '^NQUSB9530LMJPYN',
#                                               '^NQDXUSLCV',
#                                               '^NQUSBLMN',
#                                               '^NQDMXJPLMGBP',
#                                               '^NQDMXKRLMEUR',
#                                               '^NQNALMAUDN',
#                                               '^NQG9000LMEURN',
#                                               '^NQDM9000LMCADN',
#                                               '^NQFFUSHY',
#                                               '^NQDMXKRLMCAD',
#                                               '^NQDMXGBLM',
#                                               '^NQSHYLN',
#                                               '^NQNA9000LMGBP',
#                                               '^NQDMXGBLMJPYN',
#                                               '^NQG9000LMN',
#                                               '^NQDMXKRLMJPY',
#                                               '^NQUSBLMJPYN',
#                                               '^NQDM9000LMN',
#                                               '^NQDMXGBLMCAD',
#                                               '^XMI',
#                                               '^NQDMXGBLMEURN',
#                                               '^NQDMXKRGBPN',
#                                               '^NQDMXGBLMEUR',
#                                               '^NQDMXKRAUDN',
#                                               '^NQDMXKRLMJPYN',
#                                               '^NQUSBLMCADN',
#                                               '^NQDMXGBLMN',
#                                               '^NQUSB9533LMGBPN',
#                                               '^NQNALMGBPN',
#                                               '^NQGXGBLMCADN',
#                                               '^NQDMXKRLCCADN',
#                                               '^NQGXJPLMCADN',
#                                               '^BGDNTR',
#                                               '^NQUSHEIGBP',
#                                               '^NQGXJPLM',
#                                               '^NQNA9000LMAUD',
#                                               '^NQUSBLMGBP',
#                                               '^NQNALMN',
#                                               '^NQUSB9000LMAUD',
#                                               '^NQNA9000LM',
#                                               '^NQFFUSLV',
#                                               '^NQGXJPLMAUDN',
#                                               '^NQUSLVN',
#                                               '^NQGIHEIN',
#                                               '^NQCAPST',
#                                               '^NQUSB9530LMEURN',
#                                               '^NQ96DIVUS',
#                                               '^NQUSB9530LMAUD',
#                                               '^DJI',
#                                               '^NQDMXKRLCGBP',
#                                               '^NQDMXKRLM',
#                                               '^NQUSB9533LMJPY',
#                                               '^NQDM9000LMGBP',
#                                               '^NQDMXKRLC',
#                                               '^NQNALMGBP',
#                                               '^NQDMXJPLMJPYN',
#                                               '^NQG9000LMEUR',
#                                               '^NQGXGBLM',
#                                               '^NQG9000LMCAD',
#                                               '^NQGMOI',
#                                               '^NQDMXKRN',
#                                               '^NQUSMLTCVN',
#                                               '^NQCRDN',
#                                               '^NQUSB9533LM',
#                                               '^NQDMXJPLMEURN',
#                                               '^NQG9000LMJPY',
#                                               '^NQFFUSLVN',
#                                               '^NQNA9000LMJPYN',
#                                               '^NQDMXJPLM',
#                                               '^NQDMXKREUR',
#                                               '^NQUSB9533LMAUDN',
#                                               '^NQGXJPLMGBP',
#                                               '^NQDM9000LMAUDN',
#                                               '^NQDMXKRLMEURN',
#                                               '^NQUSBLMAUD',
#                                               '^NQGXGBLMGBP',
#                                               '^NQDMXKRCAD',
#                                               '^NQNA9000LMEURN',
#                                               '^DJA',
#                                               '^DAAXMLPREIT',
#                                               '^NQDXUSMLTCV',
#                                               '^NQUSB9533LMCAD',
#                                               '^NQUSB9000LMAUDN',
#                                               '^NQUSB9000LMGBP',
#                                               '^NQDXUSLCEURN',
#                                               '^NQUSB9533LMEUR',
#                                               '^NQNA9000LMAUDN',
#                                               '^NQG9000LMAUDN',
#                                               '^NQDMXKRLCAUD',
#                                               '^NQDXUSMEGAN',
#                                               '^NQNALMCAD',
#                                               '^NQUSB9530LMJPY',
#                                               '^XCI',
#                                               '^NQGXJPLMEURN',
#                                               '^NQDM9000LM',
#                                               '^NQDXUSLCGBP',
#                                               '^NQGXJPLMN',
#                                               '^NQNALMEUR',
#                                               '^NQGXGBLMEUR',
#                                               '^NQDMXKRGBP',
#                                               '^NQDM9000LMEUR',
#                                               '^NQDM9000LMCAD',
#                                               '^NQDMXGBLMGBPN',
#                                               '^BGD',
#                                               '^NQCRD',
#                                               '^NQDMXKRCADN',
#                                               '^NQGXGBLMCAD',
#                                               '^NQDMXGBLMGBP',
#                                               '^NQDMXKRLCAUDN',
#                                               '^NQDM9000LMGBPN',
#                                               '^NQDXUSLCGBPN',
#                                               '^NQG9000LM',
#                                               '^NQUSBLMGBPN',
#                                               '^NQDMXKRLMN',
#                                               '^NQUSB9530LMCADN',
#                                               '^NQUSB9533LMCADN',
#                                               '^NQUSB9533LMN',
#                                               '^NQGXJPLMAUD',
#                                               '^NQDMXGBLMAUDN',
#                                               '^NQUSHEIEUR',
#                                               '^NQUSB9000LM',
#                                               '^NQDMXJPLMJPY',
#                                               '^NQDMXKRLCGBPN',
#                                               '^NQVMVUSN',
#                                               '^NQGIHEIEURN',
#                                               '^NQDMXKREURN',
#                                               '^NQNALMJPYN',
#                                               '^NQUSB9000LMGBPN',
#                                               '^NQG9000LMGBPN',
#                                               '^NQDMXJPLMCADN',
#                                               '^NQGIHEI',
#                                               '^NQGIHEIEUR',
#                                               '^NQDMXGBLMAUD',
#                                               '^NQUSB9530LMAUDN',
#                                               '^NQUSBLMAUDN',
#                                               '^NQNA9000LMJPY',
#                                               '^NQDMXJPLMCAD',
#                                               '^NQDMXJPLMEUR',
#                                               '^NQDXUSMEGA',
#                                               '^NQDMXKRLMGBP',
#                                               '^NQDXUSLCVN',
#                                               '^NQGXGBLMAUDN',
#                                               '^NQUS500LCN',
#                                               '^NQNA9000LMCADN',
#                                               '^AXI',
#                                               '^NQUS500LCV'],
#                                'cryptoTradeable': False,
#                                'currency': 'USD',
#                                'customPriceAlertConfidence': 'HIGH',
#                                'dividendDate': 1686355200,
#                                'dividendRate': 6.64,
#                                'dividendYield': 5.21,
#                                'dividendsPerShare': 6.6,
#                                'earningsTimestamp': 1689796800,
#                                'earningsTimestampEnd': 1689796800,
#                                'earningsTimestampStart': 1689796800,
#                                'ebitda': 12643999744,
#                                'epsCurrentYear': 9.43,
#                                'epsForward': 10.02,
#                                'epsNextQuarter': 2.15,
#                                'epsTrailingTwelveMonths': 2.24,
#                                'esgPopulated': False,
#                                'exDividendDate': 1683590400,
#                                'exchange': 'NYQ',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 126.3468,
#                                'fiftyDayAverageChange': 1.8331909,
#                                'fiftyDayAverageChangePercent': 0.014509199,
#                                'fiftyTwoWeekHigh': 153.21,
#                                'fiftyTwoWeekHighChange': -25.030014,
#                                'fiftyTwoWeekHighChangePercent': -0.16337062,
#                                'fiftyTwoWeekLow': 115.55,
#                                'fiftyTwoWeekLowChange': 12.62999,
#                                'fiftyTwoWeekLowChangePercent': 0.109303236,
#                                'fiftyTwoWeekRange': '115.55 - 153.21',
#                                'firstTradeDateMilliseconds': -252322200000,
#                                'floatShares': 906973920,
#                                'forwardPE': 12.792414,
#                                'fullExchangeName': 'NYSE',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'heldPercentInsiders': 0.087,
#                                'heldPercentInstitutions': 59.409,
#                                'language': 'en-US',
#                                'longName': 'International Business Machines '
#                                            'Corporation',
#                                'market': 'us_market',
#                                'marketCap': 116393197568,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_112350',
#                                'pageViews': {'longTermTrend': 'UP',
#                                              'midTermTrend': 'UP',
#                                              'shortTermTrend': 'DOWN'},
#                                'pegRatio': 2.04,
#                                'postMarketChange': -0.24999237,
#                                'postMarketChangePercent': -0.19503228,
#                                'postMarketPrice': 127.93,
#                                'postMarketTime': 1684875614,
#                                'preMarketChange': -0.260002,
#                                'preMarketChangePercent': -0.203923,
#                                'preMarketPrice': 127.24,
#                                'preMarketTime': 1684848599,
#                                'priceEpsCurrentYear': 13.592788,
#                                'priceEpsNextQuarter': 59.6186,
#                                'priceHint': 2,
#                                'priceToBook': 5.387525,
#                                'priceToSales': 1.9211553,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteSummary': {'earnings': {'earningsChart': {'currentQuarterEstimate': 2.0,
#                                                                                'currentQuarterEstimateDate': '2Q',
#                                                                                'currentQuarterEstimateYear': 2023,
#                                                                                'earningsDate': [1689796800],
#                                                                                'quarterly': [{'actual': 2.31,
#                                                                                               'date': '2Q2022',
#                                                                                               'estimate': 2.27},
#                                                                                              {'actual': 1.81,
#                                                                                               'date': '3Q2022',
#                                                                                               'estimate': 1.77},
#                                                                                              {'actual': 3.6,
#                                                                                               'date': '4Q2022',
#                                                                                               'estimate': 3.6},
#                                                                                              {'actual': 1.36,
#                                                                                               'date': '1Q2023',
#                                                                                               'estimate': 1.26}]},
#                                                              'financialCurrency': 'USD',
#                                                              'financialsChart': {'quarterly': [{'date': '2Q2022',
#                                                                                                 'earnings': 1392000000,
#                                                                                                 'revenue': 15535000000},
#                                                                                                {'date': '3Q2022',
#                                                                                                 'earnings': -3196000000,
#                                                                                                 'revenue': 14107000000},
#                                                                                                {'date': '4Q2022',
#                                                                                                 'earnings': 2710000000,
#                                                                                                 'revenue': 16690000000},
#                                                                                                {'date': '1Q2023',
#                                                                                                 'earnings': 927000000,
#                                                                                                 'revenue': 14251000000}],
#                                                                                  'yearly': [{'date': 2019,
#                                                                                              'earnings': 9431000000,
#                                                                                              'revenue': 57714000000},
#                                                                                             {'date': 2020,
#                                                                                              'earnings': 5590000000,
#                                                                                              'revenue': 55179000000},
#                                                                                             {'date': 2021,
#                                                                                              'earnings': 5743000000,
# ...
#                                               '^NQNA9000LMJPYN',
#                                               '^NQFFUSMN',
#                                               '^NQDMXJPLM',
#                                               '^NQDMXKREUR',
#                                               '^NQGXJPLMGBP',
#                                               '^NQDM9000LMAUDN',
#                                               '^NQDMXKRLMEURN',
#                                               '^NQUSBLMAUD',
#                                               '^NQGXGBLMGBP',
#                                               '^NQDMXKRCAD',
#                                               '^NQNA9000LMEURN',
#                                               '^XQO',
#                                               '^DJA',
#                                               '^NQUSB9000LMAUDN',
#                                               '^NQUSB9000LMGBP',
#                                               '^NQDXUSLCEURN',
#                                               '^GMBNTR',
#                                               '^NQNA9000LMAUDN',
#                                               '^NQG9000LMAUDN',
#                                               '^NQDMXKRLCAUD',
#                                               '^XCQ',
#                                               '^NQDXUSMEGAN',
#                                               '^NQNALMCAD',
#                                               '^AVSPY',
#                                               '^XCI',
#                                               '^NQGXJPLMEURN',
#                                               '^NQDM9000LM',
#                                               '^NQDXUSLCGBP',
#                                               '^NQGXJPLMN',
#                                               '^NQNALMEUR',
#                                               '^NDXGBP',
#                                               '^NQGXGBLMEUR',
#                                               '^NQDMXKRGBP',
#                                               '^NQDM9000LMEUR',
#                                               '^XNDXNNRHKD',
#                                               '^NQFFUSM',
#                                               '^NQUSB9572LMGBPN',
#                                               '^NQDM9000LMCAD',
#                                               '^NQDMXGBLMGBPN',
#                                               '^XNDXNNREUR',
#                                               '^NQCRD',
#                                               '^NQDMXKRCADN',
#                                               '^NQGXGBLMCAD',
#                                               '^NQDMXGBLMGBP',
#                                               '^NQDMXKRLCAUDN',
#                                               '^XNDXNNRCAD',
#                                               '^NQDM9000LMGBPN',
#                                               '^NQDXUSLCGBPN',
#                                               '^NQUSB9570LMJPYN',
#                                               '^NQG9000LM',
#                                               '^NQUSB9572LMAUD',
#                                               '^NQUSBLMGBPN',
#                                               '^NQDMXKRLMN',
#                                               '^NQFGSLN',
#                                               '^NQGXJPLMAUD',
#                                               '^NQDMXGBLMAUDN',
#                                               '^NDXT',
#                                               '^NQUSB9000LM',
#                                               '^NQDMXJPLMJPY',
#                                               '^NQDMXKRLCGBPN',
#                                               '^NQDXUSLCGN',
#                                               '^NQVMVUSN',
#                                               '^NQUS500LCG',
#                                               '^NDXE',
#                                               '^NQDMXKREURN',
#                                               '^NQNALMJPYN',
#                                               '^NQUSB9000LMGBPN',
#                                               '^NQG9000LMGBPN',
#                                               '^NQDMXJPLMCADN',
#                                               '^NQDVRIS',
#                                               '^NQUSB9570LMCAD',
#                                               '^NQUSB9570LMEUR',
#                                               '^NQDMXGBLMAUD',
#                                               '^NQUSBLMAUDN',
#                                               '^NQNA9000LMJPY',
#                                               '^DWUSSR',
#                                               '^NQDMXJPLMCAD',
#                                               '^NQDMXJPLMEUR',
#                                               '^NQDXUSMEGA',
#                                               '^NQDMXKRLMGBP',
#                                               '^NQGXGBLMAUDN',
#                                               '^NQUS500LCN',
#                                               '^NQUSB9572LMGBP',
#                                               '^NQNA9000LMCADN'],
#                                'cryptoTradeable': False,
#                                'currency': 'USD',
#                                'customPriceAlertConfidence': 'HIGH',
#                                'dividendDate': 1684368000,
#                                'dividendRate': 0.96,
#                                'dividendYield': 0.55,
#                                'dividendsPerShare': 0.92,
#                                'earningsTimestamp': 1683234000,
#                                'earningsTimestampEnd': 1690833600,
#                                'earningsTimestampStart': 1690401600,
#                                'ebitda': 123788001280,
#                                'epsCurrentYear': 5.97,
#                                'epsForward': 6.54,
#                                'epsNextQuarter': 1.36,
#                                'epsTrailingTwelveMonths': 5.91,
#                                'esgPopulated': False,
#                                'exDividendDate': 1683849600,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 165.035,
#                                'fiftyDayAverageChange': 6.524994,
#                                'fiftyDayAverageChangePercent': 0.03953703,
#                                'fiftyTwoWeekHigh': 176.39,
#                                'fiftyTwoWeekHighChange': -4.830002,
#                                'fiftyTwoWeekHighChangePercent': -0.027382515,
#                                'fiftyTwoWeekLow': 124.17,
#                                'fiftyTwoWeekLowChange': 47.39,
#                                'fiftyTwoWeekLowChangePercent': 0.38165417,
#                                'fiftyTwoWeekRange': '124.17 - 176.39',
#                                'firstTradeDateMilliseconds': 345479400000,
#                                'floatShares': 15712029576,
#                                'forwardPE': 26.232416,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'heldPercentInsiders': 0.071,
#                                'heldPercentInstitutions': 61.232,
#                                'language': 'en-US',
#                                'longName': 'Apple Inc.',
#                                'market': 'us_market',
#                                'marketCap': 2698415702016,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_24937',
#                                'pageViews': {'longTermTrend': 'UP',
#                                              'midTermTrend': 'UP',
#                                              'shortTermTrend': 'UP'},
#                                'pegRatio': 3.64,
#                                'postMarketChange': -0.039993286,
#                                'postMarketChangePercent': -0.023311544,
#                                'postMarketPrice': 171.52,
#                                'postMarketTime': 1684875617,
#                                'preMarketChange': -1.03999,
#                                'preMarketChangePercent': -0.597011,
#                                'preMarketPrice': 173.16,
#                                'preMarketTime': 1684848599,
#                                'priceEpsCurrentYear': 28.737019,
#                                'priceEpsNextQuarter': 126.14706,
#                                'priceHint': 2,
#                                'priceToBook': 43.39995,
#                                'priceToSales': 7.0071425,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteSummary': {'earnings': {'earningsChart': {'currentQuarterEstimate': 1.19,
#                                                                                'currentQuarterEstimateDate': '2Q',
#                                                                                'currentQuarterEstimateYear': 2023,
#                                                                                'earningsDate': [1690401600,
#                                                                                                 1690833600],
#                                                                                'quarterly': [{'actual': 1.2,
#                                                                                               'date': '2Q2022',
#                                                                                               'estimate': 1.16},
#                                                                                              {'actual': 1.29,
#                                                                                               'date': '3Q2022',
#                                                                                               'estimate': 1.27},
#                                                                                              {'actual': 1.88,
#                                                                                               'date': '4Q2022',
#                                                                                               'estimate': 1.94},
#                                                                                              {'actual': 1.52,
#                                                                                               'date': '1Q2023',
#                                                                                               'estimate': 1.43}]},
#                                                              'financialCurrency': 'USD',
#                                                              'financialsChart': {'quarterly': [{'date': '2Q2022',
#                                                                                                 'earnings': 19442000000,
#                                                                                                 'revenue': 82959000000},
#                                                                                                {'date': '3Q2022',
#                                                                                                 'earnings': 20721000000,
#                                                                                                 'revenue': 90146000000},
#                                                                                                {'date': '4Q2022',
#                                                                                                 'earnings': 29998000000,
#                                                                                                 'revenue': 117154000000},
#                                                                                                {'date': '2Q2023',
#                                                                                                 'earnings': 0,
#                                                                                                 'revenue': 0}],
#                                                                                  'yearly': [{'date': 2019,
#                                                                                              'earnings': 55256000000,
#                                                                                              'revenue': 260174000000},
#                                                                                             {'date': 2020,
#                                                                                              'earnings': 57411000000,
#                                                                                              'revenue': 274515000000},
#                                                                                             {'date': 2021,
#                                                                                              'earnings': 94680000000,
#                                                                                              'revenue': 365817000000},
#                                                                                             {'date': 2022,
#                                                                                              'earnings': 99803000000,
#                                                                                              'revenue': 394328000000}]},
#                                                              'maxAge': 86400}},
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': -2.6399994,
#                                'regularMarketChangePercent': -1.5154991,
#                                'regularMarketDayHigh': 173.3794,
#                                'regularMarketDayLow': 171.275,
#                                'regularMarketDayRange': '171.275 - 173.3794',
#                                'regularMarketOpen': 173.13,
#                                'regularMarketPreviousClose': 174.2,
#                                'regularMarketPrice': 171.56,
#                                'regularMarketTime': 1684872004,
#                                'regularMarketVolume': 46405690,
#                                'revenue': 385095008000.0,
#                                'sharesOutstanding': 15728700416,
#                                'sharesShort': 124657645,
#                                'sharesShortPrevMonth': 111566048,
#                                'shortName': 'Apple Inc.',
#                                'shortPercentFloat': 0.79,
#                                'shortRatio': 2.42,
#                                'sourceInterval': 15,
#                                'symbol': 'AAPL',
#                                'targetPriceHigh': 209.0,
#                                'targetPriceLow': 118.0,
#                                'targetPriceMean': 178.88,
#                                'targetPriceMedian': 180.0,
#                                'totalCash': 55872000000.0,
#                                'tradeable': False,
#                                'trailingAnnualDividendRate': 0.92,
#                                'trailingAnnualDividendYield': 0.005281286,
#                                'trailingPE': 29.028765,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 152.18365,
#                                'twoHundredDayAverageChange': 19.376343,
#                                'twoHundredDayAverageChangePercent': 0.12732211,
#                                'typeDisp': 'Equity'}]}}
